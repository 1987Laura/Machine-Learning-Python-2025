# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.datasets import make_regression

# %%
make_regression(n_samples = 3, n_features =2)
# Out:
# (array([[-0.09671412, -1.53916766],
#         [-1.25236911,  0.07644793],
#         [-0.95052567,  1.35882627]]),
#  array([-138.44245291, -111.50194464,   24.67803432]))

# %%
x,y = make_regression(n_samples = 10, n_features =1)
plt.scatter(x,y);

# %%
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
plt.scatter(x,y);
plt.plot(x, model.coef_ * x + model.intercept_)

# %% [markdown]
# Adaugare NOISE ( zgomot)

# %%
x,y =  make_regression(n_samples = 100, n_features =1, noise=10)
model = LinearRegression()
model.fit(x,y)
plt.scatter(x,y);
plt.plot(x, model.coef_ * x + model.intercept_)

# %%
model.predict([[1]])
# Out:
# array([51.11841268])

# %%
knn_model = KNeighborsRegressor()
knn_model
# Out:
# KNeighborsRegressor()

# %%
knn_model.fit(x,y)
# Out:
# KNeighborsRegressor()

# %%
model.predict([[1]])
# Out:
# array([51.11841268])
