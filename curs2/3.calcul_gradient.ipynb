# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.rcParams["figure.figsize"] = [3.3, 3.3]

# %%
apartamente = [(37,65), (55,80), (80,120), (60,95), (92,205), (41,75), (170,400), (145, 367), (82, 205), (72, 198)]

apartamente = np.array(apartamente)

apartamente = apartamente[ apartamente [:,0].argsort()]
suprafete, preturi = apartamente[:, 0], apartamente[:,1]

# %%
def lin_plot(x,y,a,b):
    plt.scatter(x,y);
    f = lambda x: a * x +b
    plt.plot(x,list(map(f, x)));

# %%
a= 0
b = 0
lin_plot(suprafete, preturi, a, b)

# %%
preturi_calculate = a * suprafete + b

suma_reziduala = 1/ (2 * preturi.size) * np.sqrt(((preturi - preturi_calculate) ** 2).sum())

suma_reziduala
# Out:
# 33.82373427047936

# %%
derivata_a = 2 * np.sum((preturi_calculate - preturi) * suprafete)
derivata_b = 2 * np.sum((preturi_calculate - preturi))

"de_A", derivata_a, "d_B", derivata_b
# Out:
# ('de_A', -392642, 'd_B', -3620)

# %%
LEARNING_RATE = 0.001

# %%
noul_a = a - derivata_a * LEARNING_RATE
noul_b = b - derivata_b * LEARNING_RATE

noul_a, noul_b
# Out:
# (392.642, 3.62)

# %%
lin_plot(suprafete, preturi, noul_a, noul_b)

# %% [markdown]
# # Rescriere intr-o functie

# %%
a= 0
b = 0
cost = []

def calculeaza_gradient():
    global a, b
    LEARNING_RATE = 0.00001
    preturi_calculate = a * suprafete + b
    suma_reziduala = (1/ (2 * preturi.size)) * np.sqrt(((preturi - preturi_calculate) ** 2).sum())
    cost.append(suma_reziduala)
    print("noua suma reziduala", suma_reziduala)
    derivata_a = (1/preturi.size) * np.sum((preturi_calculate - preturi) * suprafete)
    derivata_b = (1/preturi.size) *  np.sum((preturi_calculate - preturi))

    a = a - derivata_a * LEARNING_RATE
    b = b - derivata_b * LEARNING_RATE
    
    lin_plot(suprafete, preturi, a, b)

# %%
lin_plot(suprafete, preturi, a, b)

# %%
calculeaza_gradient()
# Out:
# noua suma reziduala 14.54733911993856

# %% [markdown]
# # RESTART

# %%
import time

# %%
a= 0
b = 0
EPOCI = 100
cost = []
for i in range(EPOCI):
    calculeaza_gradient()
    #time.sleep(2)
# Out:
# noua suma reziduala 33.82373427047936
# noua suma reziduala 30.978101720123483
# noua suma reziduala 28.38524251706885
# noua suma reziduala 26.023913691335466
# noua suma reziduala 23.874743692078315
# noua suma reziduala 21.920068869043018
# noua suma reziduala 20.143782634388618
# noua suma reziduala 18.531195862866387
# noua suma reziduala 17.068907193471624
# noua suma reziduala 15.744682020435855

# %% [markdown]
# #Plotting costuri

# %%
costuri_plotat = []

for c in cost:
    costuri_plotat.append(c)
    plt.scatter(costuri_plotat,costuri_plotat);
    plt.show()
    time.sleep(2)
