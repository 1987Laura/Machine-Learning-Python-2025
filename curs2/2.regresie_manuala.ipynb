# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
apartamente = [(37,65), (55,90), (80,120), (60,95), (92,205), (41,75), (170,400), (145, 367), (82, 205), (72, 198)]

apartamente = np.array(apartamente)

apartamente = apartamente[ apartamente [:,0].argsort()]
suprafete, preturi = apartamente[:, 0], apartamente[:,1]

# %%
plt.rcParams["figure.figsize"] = [3.3, 3.3]

# %%
def lin_plot(x,y,a,b):
    plt.scatter(x,y);
    f = lambda x: a * x +b
    plt.plot(x,list(map(f, x)));

# %%
lin_plot(suprafete, preturi, 0, 0)

# %%
lin_plot(x =suprafete, y= preturi, a=1, b=30)

# %% [markdown]
# # preturile reale

# %%
preturi
# Out:
# array([ 65,  75,  90,  95, 198, 120, 205, 205, 367, 400])

# %%
suprafete
# Out:
# array([ 37,  41,  55,  60,  72,  80,  82,  92, 145, 170])

# %%
a=1
b=1
preturi_calculate = a*  suprafete + 1
preturi_calculate
# Out:
# array([ 38,  42,  56,  61,  73,  81,  83,  93, 146, 171])

# %%
preturi - preturi_calculate
# Out:
# array([ 27,  33,  34,  34, 125,  39, 122, 112, 221, 229])

# %%
(preturi - preturi_calculate) ** 2
# Out:
# array([  729,  1089,  1156,  1156, 15625,  1521, 14884, 12544, 48841,
#        52441])

# %%
((preturi - preturi_calculate) ** 2).sum()
# Out:
# 149986

# %%
np.sqrt(((preturi - preturi_calculate) ** 2).sum())
# Out:
# 387.28026027671484

# %%
lin_plot(x =suprafete, y= preturi, a=1, b=1)

# %%
a=2
b=1
preturi_calculate = a *  suprafete + b
preturi_calculate

np.sqrt(((preturi - preturi_calculate) ** 2).sum())
# Out:
# 130.49137902558928

# %%
lin_plot(x =suprafete, y= preturi, a=2, b=1)

# %% [markdown]
# # intuitie ML

# %% [markdown]
# # am modificat a

# %%
a=1
b=2
preturi_calculate = a *  suprafete + b
preturi_calculate

np.sqrt(((preturi - preturi_calculate) ** 2).sum())
# Out:
# 384.7648632606673

# %% [markdown]
# 1. incepem cu a si b random, sau 0 si 0,
# 2. ajustam a si b
