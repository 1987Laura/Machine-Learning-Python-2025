# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
apartamente = [(37,65), (55,90), (80,120), (60,95), (92,205), (41,75), (170,400), (145, 367), (82, 205), (72, 198)]

apartamente = np.array(apartamente)

apartamente = apartamente[ apartamente [:,0].argsort()]

# %%
suprafete, preturi = apartamente[:, 0], apartamente[:,1]

# %%
suprafete
# Out:
# array([ 37,  41,  55,  60,  72,  80,  82,  92, 145, 170])

# %%
plt.scatter(suprafete, preturi)
plt.xlabel('suprafata')
plt.ylabel('preturi')
# Out:
# Text(0, 0.5, 'preturi')

# %%
plt.scatter(suprafete, preturi)
plt.plot(suprafete, preturi)

# %% [markdown]
# # pip install scikit-learn

# %% [markdown]
# # import sklearn

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
suprafete.reshape(-1,1)
# Out:
# array([[ 37],
#        [ 41],
#        [ 55],
#        [ 60],
#        [ 72],
#        [ 80],
#        [ 82],
#        [ 92],
#        [145],
#        [170]])

# %%
model.fit(suprafete.reshape(-1,1), preturi)
# Out:
# LinearRegression()

# %%
model.coef_, model.intercept_
# Out:
# (array([2.68089484]), -41.58662971860804)

# %%
def f(x):
    return 2.68089484 * x - 41.58662971860804

# %%
plt.scatter(suprafete, preturi);
plt.plot(suprafete, list(map(f, suprafete)))

# %%
model.predict([[85], [115]])
# Out:
# array([186.28943175, 266.71627697])
