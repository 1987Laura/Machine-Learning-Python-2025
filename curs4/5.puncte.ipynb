# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")
df
# Out:
#         coord_x     coord_y categoria
# 0    225.734576  325.667185         a
# 1    231.227775  400.402582         a
# 2    258.267868  346.314220         a
# 3    261.708723  345.807666         a
# 4    239.403182  363.583517         a
# ..          ...         ...       ...
# 142  503.433833  318.417733         a
# 143  514.947493  370.072039         a
# 144  509.387058  364.732876         a
# 145  505.594765  313.277219         a
# 146  487.546634  370.944682         a
#
# [147 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df["coord_x"], df["coord_y"], c=df["categoria"]== "a");

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model
# Out:
# KNeighborsClassifier()

# %%
model.fit(df[["coord_x","coord_y"]], df["categoria"] )
# Out:
# KNeighborsClassifier()

# %%
model.predict([[400,200]])
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array(['a'], dtype=object)

# %%
from sklearn.neural_network import
